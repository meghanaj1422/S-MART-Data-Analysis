# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\m7785\Downloads\Data Analysis5 (1).csv")
df
# Out:
#                Name  Gender      Age  \
# 0    abhishek kumar    Male  17 - 25
# 1        Aditya Raj    Male  17 - 25
# 2     Akhil Tummala    Male  17 - 25
# 3       Amiya Vatsa    Male  17 - 25
# 4   Anand Kumar Rai    Male  17 - 25
# ..              ...     ...      ...
# 72             Umar  Female  17 - 25
# 73          Varun.j    Male  17 - 25
# 74    VIMLESH YADAV    Male  17 - 25
# 75  Vipin Tembhurne    Male  17 - 25
# 76       Yash Kumar    Male  17 - 25
#
#                                              Products  Dairy  Grocery  \
# 0                                             Grocery  False     True
# 1   Dairy, Grocery, Health and Beauty, Beverages, ...   True     True
# 2                   Dairy, Grocery, Health and Beauty   True     True
# 3   Dairy, Grocery, Health and Beauty, Beverages, ...   True     True
# 4           Dairy, Grocery, Health and Beauty, Bakery   True     True
# ..                                                ...    ...      ...
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of                Name  Gender      Age  \
# 0    abhishek kumar    Male  17 - 25
# 1        Aditya Raj    Male  17 - 25
# 2     Akhil Tummala    Male  17 - 25
# 3       Amiya Vatsa    Male  17 - 25
# 4   Anand Kumar Rai    Male  17 - 25
# ..              ...     ...      ...
# 72             Umar  Female  17 - 25
# 73          Varun.j    Male  17 - 25
# 74    VIMLESH YADAV    Male  17 - 25
# 75  Vipin Tembhurne    Male  17 - 25
# 76       Yash Kumar    Male  17 - 25
#
#                                              Products  Dairy  Grocery  \
# 0                                             Grocery  False     True
# 1   Dairy, Grocery, Health and Beauty, Beverages, ...   True     True
# 2                   Dairy, Grocery, Health and Beauty   True     True
# 3   Dairy, Grocery, Health and Beauty, Beverages, ...   True     True
# 4           Dairy, Grocery, Health and Beauty, Bakery   True     True
# ...

# %%
df.describe()
# Out:
#           Rating
# count  77.000000
# mean    3.688312
# std     0.862367
# min     2.000000
# 25%     3.000000
# 50%     4.000000
# 75%     4.000000
# max     5.000000

# %%
df.isnull().sum()
# Out:
# Name                 0
# Gender               0
# Age                  0
# Products             0
# Dairy                0
# Grocery              0
# Health and Beauty    0
# Beverages            0
# Bakery               0
# others               0
# Payment methods      0
# Sales-Person type    0
# Times of Day         0
# Times of Week        0
# Discount Applied     0
# Size                 0
# Rating               0
# Often Visiters       0
# Favorite             0
# Suggestion           1
# dtype: int64

# %%
df.nunique()
# Out:
# Name                 77
# Gender                2
# Age                   2
# Products             33
# Dairy                 2
# Grocery               2
# Health and Beauty     2
# Beverages             2
# Bakery                2
# others                2
# Payment methods       2
# Sales-Person type     3
# Times of Day          4
# Times of Week         7
# Discount Applied      3
# Size                  3
# Rating                4
# Often Visiters        2
# Favorite             42
# Suggestion           22
# dtype: int64

# %%
df.sort_values(by = "Age").head()
# Out:
#                Name  Gender      Age                  Products  Dairy  \
# 0    abhishek kumar    Male  17 - 25                   Grocery  False
# 52  Priyanka bharti  Female  17 - 25                 Beverages  False
# 51      PRITAM SAHA    Male  17 - 25         Beverages, Bakery  False
# 50         Pranathi  Female  17 - 25            Bakery, Others  False
# 49            Pavan    Male  17 - 25  Dairy, Beverages, Bakery   True
#
#     Grocery  Health and Beauty  Beverages  Bakery  others Payment methods  \
# 0      True              False      False   False   False  Online Payment
# 52    False              False       True   False   False  Online Payment
# 51    False              False       True    True    True  Online Payment
# 50    False              False      False    True    True       Cash/Card
# 49    False              False       True    True    True  Online Payment
#
#     Sales-Person type Times of Day Times of Week Discount Applied  \
# ...
